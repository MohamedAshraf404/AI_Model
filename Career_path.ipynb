# %%
import pandas as pd
import re

# Load your CSV file
file_path = 'Indeed_10k.csv'
data = pd.read_csv(file_path)

# Check for missing values
print("Missing values before cleaning:")
print(data.isnull().sum())
# Out:
# Missing values before cleaning:
# Name          0
# Company       0
# City          0
# Ratings    3776
# Summary       0
# Date          0
# dtype: int64

# %%
# Fill missing Ratings with the mean value, or you can drop them if not needed
data['Ratings'] = data['Ratings'].fillna(data['Ratings'].mean())

# %%
# List of tech skills to search for in job summaries
skills_list = ['Python', 'Java', 'C#', 'C++', 'SQL', 'JavaScript', 'HTML', 'CSS', 
               'Ruby', 'PHP', 'Go', 'Swift', 'Kotlin', 'R', 'Matlab', 'Perl', 
               'Scala', 'Rust', 'Django', 'Flask', 'Node.js', 'React', 'Angular', 
               'Vue.js', 'Docker', 'Kubernetes', 'AWS', 'Azure', 'GCP']

# Function to extract skills from the 'Summary' column
def extract_skills(summary):
    found_skills = [skill for skill in skills_list if re.search(rf'\b{skill}\b', summary, re.IGNORECASE)]
    return ', '.join(found_skills) if found_skills else None

# Apply the function to create a new 'Skills' column
data['Skills'] = data['Summary'].apply(extract_skills)

# Drop rows where 'Skills' is missing, or handle accordingly
data = data.dropna(subset=['Skills'])

# Show cleaned dataset
print(data[['Name', 'Company', 'City', 'Skills']].head())

# Save the cleaned data to a new CSV
data.to_csv('cleaned_Indeed_10k.csv', index=False)
# Out:
#                                                 Name              Company  \
# 0                      Entry level Software Engineer  CapitalPlanHoldings
# 1                           Junior Software Engineer            FormSwift
# 4                         Software Engineer (Python)                Imgix
# 6  AppD Software Engineer Bachelor's (Intern) Uni...        Cisco Systems
# 7            Software Engineer - University Graduate               PayPal
#
#                                          City              Skills
# 0                           San Francisco, CA           Java, C++
# 1                           San Francisco, CA  Python, JavaScript
# 4                           San Francisco, CA              Python
# 6                           San Francisco, CA                Java
# 7  San Francisco, CA 94107 (South Beach area)   Python, Java, C++

# %%
# Load the cleaned dataset
file_path = 'cleaned_Indeed_10k.csv'
data = pd.read_csv(file_path)

data.head()
# Out:
#                                                 Name              Company  \
# 0                      Entry level Software Engineer  CapitalPlanHoldings
# 1                           Junior Software Engineer            FormSwift
# 2                         Software Engineer (Python)                Imgix
# 3  AppD Software Engineer Bachelor's (Intern) Uni...        Cisco Systems
# 4            Software Engineer - University Graduate               PayPal
#
#                                          City   Ratings  \
# 0                           San Francisco, CA  3.918493
# 1                           San Francisco, CA  3.918493
# 2                           San Francisco, CA  3.918493
# 3                           San Francisco, CA  4.100000
# 4  San Francisco, CA 94107 (South Beach area)  3.900000
#
#                                              Summary          Date  \
# 0  Programming experience using C#, C++, or Java ...    2 days ago
# 1  Building new product features across the back ...  30+ days ago
# 2  Comfortable developing in Python (or similar)....    5 days ago
# 3  Java server side web frameworks (SpringMVC, St...    4 days ago
# 4  Solid experience working with or familiarity a...  30+ days ago
#
#                Skills
# 0           Java, C++
# 1  Python, JavaScript
# 2              Python
# 3                Java
# 4   Python, Java, C++

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report
from sklearn.linear_model import LogisticRegression

# Features (Skills) and Target (Job Title)
X = data['Skills']
y = data['Name']  # Job title as the label

# Convert the Skills column into numerical data using TF-IDF
vectorizer = TfidfVectorizer()
X_transformed = vectorizer.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_transformed, y, test_size=0.2, random_state=42)

# %%
# Model: Multinomial Naive Bayes (can also use Logistic Regression)
model = MultinomialNB()
model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_test)

# Model evaluation
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 61.73%
# Classification Report:
#                                                                  precision    recall  f1-score   support
#
#                                  AI / Machine Learning Engineer       0.00      0.00      0.00         1
#                                   API Backend Software Engineer       0.00      0.00      0.00         1
#                                                Android Engineer       0.13      1.00      0.23        21
#                                            AppD DevOps Engineer       0.00      0.00      0.00        32
#                                               Backend Developer       0.67      0.41      0.51        34
#                                                Backend Engineer       0.00      0.00      0.00         3
#                                       Backend Software Engineer       0.00      0.00      0.00         2
#                                     CUSTOMER SUCCESS SPECIALIST       0.00      0.00      0.00         1
#                        Computer Scientist ( Software Engineer )       0.00      0.00      0.00         1
#                                    Customer Operations Engineer       0.00      0.00      0.00         2
#                                  Entry-Level Software Developer       0.00      0.00      0.00         1
#              Experienced Software Engineer, Behavior Prediction       0.00      0.00      0.00         2
#                                               Firmware Engineer       0.00      0.00      0.00         1
#                                              Front End Engineer       0.00      0.00      0.00         4
#                                              Front-End Engineer       0.00      0.00      0.00         1
#                                     Frontend Engineer, Identity       0.00      0.00      0.00         5
#                                             Full Stack Engineer       0.00      0.00      0.00         1
#                             Full Stack Engineer (Ruby Back End)       0.81      1.00      0.90        26
#                                        Full Stack Engineer - SF       0.00      0.00      0.00         1
#                                    Full Stack Software Engineer       0.00      0.00      0.00         1
#       Full Stack Software Engineer: Internal Tools, Product Web       0.00      0.00      0.00         1
#                                             Full-Stack Engineer       0.00      0.00      0.00         1
#                                                     Go Engineer       0.00      0.00      0.00         6
#                          HelloSign Lead Software Engineer, Test       0.00      0.00      0.00         3
#                                Infrastructure Software Engineer       0.75      0.94      0.83        48
#                               Java Developers (Immediate roles)       0.00      0.00      0.00        20
#                                        Java Front End Developer       0.00      0.00      0.00         1
#                               Java Full Stack Software Engineer       0.00      0.00      0.00         1
#                                          Java Software Engineer       0.00      0.00      0.00        21
#                                         JavaScript SDK Engineer       0.00      0.00      0.00         1
#                    Junior Java Backend Engineer - San Mateo, CA       1.00      1.00      1.00        55
#                                      Lead Software Engineer, UI       0.00      0.00      0.00         1
#                             ML Infrastructure Software Engineer       0.00      0.00      0.00         1
#                                       Machine Learning Engineer       0.62      1.00      0.77        38
#                           Machine Learning Engineer - Health ML       0.60      1.00      0.75        44
#                                 Microservices Software Engineer       0.00      0.00      0.00         1
#                              Mobile Software Engineer (Android)       0.00      0.00      0.00         1
#                                     Principal Software Engineer       0.41      1.00      0.58        29
#                        Principal Software Engineer (Full Stack)       0.00      0.00      0.00         1
#                                                Python Developer       0.00      0.00      0.00         1
#                                                     QA Engineer       0.00      0.00      0.00         1
#                                      React Engineer (Front-End)       0.00      0.00      0.00         4
#                                     Rendering Software Engineer       0.00      0.00      0.00         1
#                   Senior Fullstack Software Engineer, Bitbucket       0.00      0.00      0.00         1
#                                        Senior Software Engineer       0.00      0.00      0.00        10
#                            Senior Software Engineer (Front End)       0.00      0.00      0.00         3
#                            Senior Software Engineer (Front-End)       0.00      0.00      0.00         3
#                  Senior Software Engineer - Core Data Libraries       0.00      0.00      0.00         1
#                                          Software Engineer, ERP       0.00      0.00      0.00         1
#                                     Software Engineer, Frontend       0.00      0.00      0.00         2
#                 Software Engineer, Full Stack (Personalization)       0.00      0.00      0.00         1
#                   Software Engineer, Full Stack (Ruby/Rails/JS)       0.00      0.00      0.00         2
#                               Software Engineer, Infrastructure       0.00      0.00      0.00         1
#              Software Engineer, Intern (Health Algorithms Team)       0.00      0.00      0.00         1
#                         Software Engineer, Intern (Summer 2020)       0.00      0.00      0.00         1
#                    Software Engineer, JavaScript and React SDKs       0.00      0.00      0.00         1
#                         Software Engineer, Numerical Algorithms       0.00      0.00      0.00         1
#                                     Software Engineer, Payments       0.00      0.00      0.00         1
#                  Software Engineer, Platform (New College Grad)       0.00      0.00      0.00         1
#                                       Software Engineer, Python       0.00      0.00      0.00         1
#                                       Software Engineer, Search       0.00      0.00      0.00         1
#                          Software Engineer, Systems - Discovery       0.00      0.00      0.00         1
#                                  Software Engineer- SS&C Advent       0.00      0.00      0.00         1
#                                     Software Engineer: Frontend       0.00      0.00      0.00         1
#                                 Software Engineering - Frontend       0.93      1.00      0.96        26
#                                           Software QE Developer       0.00      0.00      0.00         1
#                           Software Testing Development Engineer       0.00      0.00      0.00         3
#                                           Sr Front End Engineer       0.00      0.00      0.00         1
#               Sr. Full Stack Software Engineer (Audiences Team)       0.90      1.00      0.95        19
#                                  Sr. Software Engineer, Backend       0.74      1.00      0.85        29
#                      Sr. Software Engineer, Frontend - Frontend       0.00      0.00      0.00         2
#             Sr. Software Engineer, Frontend, Website - Frontend       0.00      0.00      0.00         3
#                                         Staff Software Engineer       0.00      0.00      0.00         7
#                                Staff Software Engineer (AppSec)       0.00      0.00      0.00         1
#                Staff Software Engineer (Kafka) - Messaging Team       0.00      0.00      0.00         1
# Staff Software Engineer (REF24580T) - Visa Digital Developer...       0.00      0.00      0.00        19
#              Staff Software Engineer - C++ (System Performance)       0.00      0.00      0.00         2
#                                 Staff Software Engineer - Ecomm       0.00      0.00      0.00         3
# Staff Software Engineer, Real Time Payments (REF24378W) - Vi...       0.00      0.00      0.00        15
#                               Staff Software Engineer, Workflow       0.00      0.00      0.00         1
#                Staff Software Engineer- Full Stack - AWS - Java       0.00      0.00      0.00         1
#                          Summer 2020 Intern - Software Engineer       0.00      0.00      0.00         1
# Summer Intern: Commerce & Identity - Software Engineer Inter...       0.00      0.00      0.00         1
#                                       Thermal Research Engineer       0.00      0.00      0.00         1
#                                          Web Developer Engineer       0.41      1.00      0.58        40
#                                                    iOS Engineer       0.00      0.00      0.00         1
#                                         iOS Software Engineer I       0.00      0.00      0.00        14
#
#                                                        accuracy                           0.62       980
#                                                       macro avg       0.11      0.14      0.11       980
#                                                    weighted avg       0.52      0.62      0.54       980
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
lg_model = LogisticRegression(max_iter=1000)
lg_model.fit(X_train, y_train)

# Predict on the test set
y_pred = lg_model.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)

# Print the accuracy
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 68.88%

# %%
from catboost import CatBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# Convert the Skills column into numerical data using TF-IDF
from sklearn.feature_extraction.text import TfidfVectorizer


# Initialize CatBoostClassifier
catboost_model = CatBoostClassifier(iterations=1000, depth=6, learning_rate=0.1, verbose=False)

# Train the model
catboost_model.fit(X_train, y_train)

# Predictions
y_pred = catboost_model.predict(X_test)

# Model evaluation
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy:
#                 Software Engineer, Data Products - Doctor Match       1.00      1.00      1.00         2
#                             Software Engineer, Desktop Platform       1.00      1.00      1.00         1
#                                          Software Engineer, ERP       0.00      0.00      0.00         1
#                                     Software Engineer, Frontend       1.00      0.50      0.67         2
#                 Software Engineer, Full Stack (Personalization)       0.00      0.00      0.00         1
#                   Software Engineer, Full Stack (Ruby/Rails/JS)       0.00      0.00      0.00         2
#                               Software Engineer, Infrastructure       0.00      0.00      0.00         1
#              Software Engineer, Intern (Health Algorithms Team)       0.00      0.00      0.00         1
#                         Software Engineer, Intern (Summer 2020)       0.00      0.00      0.00         1
#                    Software Engineer, JavaScript and React SDKs       1.00      1.00      1.00         1
#                         Software Engineer, Numerical Algorithms       0.00      0.00      0.00         1
#                                     Software Engineer, Payments       0.00      0.00      0.00         1
#                  Software Engineer, Platform (New College Grad)       0.00      0.00      0.00         1
#                                       Software Engineer, Python       0.00      0.00      0.00         1
#                                       Software Engineer, Search       0.00      0.00      0.00         1
#                          Software Engineer, Systems - Discovery       0.00      0.00      0.00         1
#                                  Software Engineer- SS&C Advent       0.00      0.00      0.00         1
#                                     Software Engineer: Frontend       0.00      0.00      0.00         1
#                                 Software Engineering - Frontend       0.96      1.00      0.98        26
#                                           Software QE Developer       0.00      0.00      0.00         1
#                           Software Testing Development Engineer       0.00      0.00      0.00         3
#                                           Sr Front End Engineer       0.00      0.00      0.00         1
#               Sr. Full Stack Software Engineer (Audiences Team)       0.95      1.00      0.97        19
#                                  Sr. Software Engineer, Backend       0.85      1.00      0.92        29
#                      Sr. Software Engineer, Frontend - Frontend       0.67      1.00      0.80         2
#             Sr. Software Engineer, Frontend, Website - Frontend       0.00      0.00      0.00         3
#                                         Staff Software Engineer       0.00      0.00      0.00         7
#                                Staff Software Engineer (AppSec)       0.00      0.00      0.00         1
#                Staff Software Engineer (Kafka) - Messaging Team       0.00      0.00      0.00         1
# Staff Software Engineer (REF24580T) - Visa Digital Developer...       0.00      0.00      0.00        19
#              Staff Software Engineer - C++ (System Performance)       0.00      0.00      0.00         2
#                                 Staff Software Engineer - Ecomm       0.00      0.00      0.00         3
# Staff Software Engineer, Real Time Payments (REF24378W) - Vi...       1.00      1.00      1.00        15
#                               Staff Software Engineer, Workflow       1.00      1.00      1.00         1
#                Staff Software Engineer- Full Stack - AWS - Java       0.00      0.00      0.00         1
#                          Summer 2020 Intern - Software Engineer       0.00      0.00      0.00         1
# Summer Intern: Commerce & Identity - Software Engineer Inter...       0.00      0.00      0.00         1
#                                       Thermal Research Engineer       0.00      0.00      0.00         1
#                                          Web Developer Engineer       0.91      1.00      0.95        40
#                                                    iOS Engineer       0.00      0.00      0.00         1
#                                           iOS Software Engineer       0.00      0.00      0.00         0
#                                         iOS Software Engineer I       0.00      0.00      0.00        14
#
#                                                        accuracy                           0.71       980
#                                                       macro avg       0.23      0.26      0.23       980
#                                                    weighted avg       0.63      0.71      0.66       980
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Save the CatBoost model
catboost_model.save_model('catboost_model.cbm')

# %%
import pickle

# Save the TF-IDF vectorizer
with open('tfidf_vectorizer.pkl', 'wb') as f:
    pickle.dump(vectorizer, f)
